# %% [markdown]
# # Practical session n°7
#
# Notions:
# - Quantile regression
# - Pinball Loss
#
#
# Duration: 1 h 30
#
# In this practical, we immerse ourselves again in the context where the training inputs ($x$) and targets ($y$) are images of the same spatial dimensions. However, we assume that the dependence of $y$ on $x$ is probabilistic in nature. In other words, there exist conditional laws $p(y | x)$, and these laws need to be characterized.
#
# Here, we limit ourselves to conditional marginals, meaning the laws $p(y_{i,j} | x)$ where $y_{i,j}$ represents the value of the target $y$ at the pixel $(i,j)$. To characterize these laws, several approaches are possible. For instance, one can attempt to estimate their quantiles or moments. The following exercises illustrate a method for estimating quantiles.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms

# %%
! git clone https://github.com/nanopiero/ML_S5_etudiants
import sys
sys.path.append('ML_S5_etudiants/practicals/P7')
from utils_P7 import gen_proba, voir_batch2D, UNet
# Out:
# Cloning into 'ML_S5_etudiants'...
# remote: Enumerating objects: 368, done.
# remote: Counting objects: 100% (200/200), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 368 (delta 108), reused 88 (delta 45), pack-reused 168 (from 2)
# Receiving objects: 100% (368/368), 20.12 MiB | 26.01 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %% [markdown]
# **Exercise 1**: on the PINBALL loss
#
# As seen in the previous practical session n°4, using the Mean Absolute Error (MAE) led the model to provide the conditional median, which is a particular quantile. To estimate other quantiles, it is sufficient to modify the MAE.
#
# This is what we are going to do on a simple problem where the link between the input and the target is defined by:
# $$y_{i,j} \sim \mathcal{N}(\mu(x_{i,j}), \sigma(x_{i,j})) $$
# where $\mu$ and $\sigma$ are a priori unknown.
#
# The gen_proba function from the utile.py module will allow us to "explore" our dataset, or in other words, to sample the random pair $(x, y)$.

# %%
# sampling (x,y) :

input, target = gen_proba(6)
# Inputs
fig0 = plt.figure(0, figsize=(36, 6))
voir_batch2D(input, 6, fig0, k=0, min_scale=0,max_scale=1)

# Targets
fig1 = plt.figure(1, figsize=(36, 6))
voir_batch2D(target, 6, fig1, k=0, min_scale=0,max_scale=1)

# %% [markdown]
# Let's consider the cost function be defined at the pixel level by:
# $$\mathcal{L}_t(y,z) =  \rho_t(z - y) $$
# where:
# $$\rho_t(u) = t \times max(u,0) + (t-1) \times min(u,0) $$
#
# **Q1** Plot the graph of $\rho_t$ for different values of $t$ in the range [0, 1] using *matplotlib.pyplot*.
# How does $\mathcal{L}_t$ generalize the MAE?

# %%
def rho_t(u, t):
    return t * torch.max(u, torch.zeros_like(u)) + (t - 1) * torch.min(u, torch.zeros_like(u))

u = torch.linspace(-5, 5, 100)
t_values = [0.1, 0.25, 0.5, 0.75, 0.9]

plt.figure(figsize=(4, 2))
for t_val in t_values:
    rho_values = rho_t(u, torch.tensor(t_val))
    plt.plot(u.numpy(), rho_values.numpy(), label=f't = {t_val}')

plt.xlabel('u')
plt.ylabel('rho_t(u)')
plt.title('Graph of Pinball Loss function rho_t(u) for different t values')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Q2** In the following cell, code a cost function adapted to the estimation of $t$-th quantiles (use *.clamp*( ))

# %%
def rho(u,t):
        loss = rho_t(u,t)
        return loss

# %% [markdown]
# **Q3** Train a U-Net to estimate the ninth decile.

# %%
def criterion(output, target):
  return torch.mean(rho(output-target, 0.9))

# %%
fcn = UNet(1,1,8).cuda()
import torch.optim as optim
optimizer = optim.Adam(fcn.parameters(), 10**(-3))

# %%
device = "cuda:0"

# %%
nepochs = 50
nbatches = 100
batchsize = 64

train_losses = []

for epoch in range(nepochs):

    print("Epoch " + str(epoch))
    epoch_losses  = []
    for i in range(batchsize):

        input, target = gen_proba(nbatches)

        output = fcn(input.to(device))

        loss = criterion(output,target.to(device))

        loss.backward()

        epoch_losses.append(loss.cpu().detach().numpy())

        optimizer.step()

        del target, input, loss

    epoch_loss = np.mean(epoch_losses)
    train_losses.append(epoch_loss)
    print('epoch loss : \n')
    print(epoch_loss)
# Out:
# Epoch 0
# epoch loss :
#
# 0.07987405
# Epoch 1
# epoch loss :
#
# 0.025897592
# Epoch 2
# epoch loss :
#
# 0.046293117
# Epoch 3
# epoch loss :
#
# 0.05325789
# Epoch 4
# epoch loss :
#
# 0.04338353
# Epoch 5
# epoch loss :
#
# 0.028200017
# Epoch 6
# epoch loss :
#
# 0.014957255
# Epoch 7
# epoch loss :
#
# 0.007842424
# Epoch 8
# epoch loss :
#
# 0.010186775
# Epoch 9
# epoch loss :
#
# 0.007352677
# Epoch 10
# epoch loss :
#
# 0.013173196
# Epoch 11
# epoch loss :
#
# 0.020459512
# Epoch 12
# epoch loss :
#
# 0.025434364
# Epoch 13
# epoch loss :
#
# 0.028182447
# Epoch 14
# epoch loss :
#
# 0.028572436
# Epoch 15
# epoch loss :
#
# 0.026253022
# Epoch 16
# epoch loss :
#
# 0.021135665
# Epoch 17
# epoch loss :
#
# 0.013349424
# Epoch 18
# epoch loss :
#
# 0.010941947
# Epoch 19
# epoch loss :
#
# 0.031130116
# Epoch 20
# epoch loss :
#
# 0.010090472
# Epoch 21
# epoch loss :
#
# 0.022059597
# Epoch 22
# epoch loss :
#
# 0.030898076
# Epoch 23
# epoch loss :
#
# 0.037340656
# Epoch 24
# epoch loss :
#
# 0.04264099
# Epoch 25
# epoch loss :
#
# 0.048540507
# Epoch 26
# epoch loss :
#
# 0.048845917
# Epoch 27
# epoch loss :
#
# 0.04741575
# Epoch 28
# epoch loss :
#
# 0.045875512
# Epoch 29
# epoch loss :
#
# 0.041997742
# Epoch 30
# epoch loss :
#
# 0.035560716
# Epoch 31
# epoch loss :
#
# 0.026853511
# Epoch 32
# epoch loss :
#
# 0.016569072
# Epoch 33
# epoch loss :
#
# 0.014678554
# Epoch 34
# epoch loss :
#
# 0.05282732
# Epoch 35
# epoch loss :
#
# 0.016962282
# Epoch 36
# epoch loss :
#
# 0.017746657
# Epoch 37
# epoch loss :
#
# 0.028425798
# Epoch 38
# epoch loss :
#
# 0.037032574
# Epoch 39
# epoch loss :
#
# 0.04395982
# Epoch 40
# epoch loss :
#
# 0.049408063
# Epoch 41
# epoch loss :
#
# 0.053798698
# Epoch 42
# epoch loss :
#
# 0.057406053
# Epoch 43
# epoch loss :
#
# 0.05979289
# Epoch 44
# epoch loss :
#
# 0.06078997
# Epoch 45
# epoch loss :
#
# 0.060337223
# Epoch 46
# epoch loss :
#
# 0.058285136
# Epoch 47
# epoch loss :
#
# 0.054590613
# Epoch 48
# epoch loss :
#
# 0.04921966
# Epoch 49
# epoch loss :
#
# 0.04224702

# %% [markdown]
# **Q4** The ground truth is given by:
# $$ \mu(x_{i,j}) = {x}_{i,j}^2 $$
# and
# $$ \sigma(x_{i,j}) = 0.2 \times x_{i,j} $$
#
# Use [torch.distributions.normal.Normal](https://pytorch.org/docs/stable/distributions.html) to verify that the result corresponds well to the expected quantile.

# %%
# viz:
fcn.eval()
input, target = gen_proba(6)
output = fcn(input.cuda())

fig = plt.figure(0, figsize=(36, 6))
voir_batch2D(input, 6, fig, k=0, min_scale=0,max_scale=1) # inputs
fig1 = plt.figure(1, figsize=(36, 6))
voir_batch2D(output.detach().cpu(), 6, fig1, k=0, min_scale=0,max_scale=0.1) # outputs

# true quantile
mu = input*input
sigma = 0.2*input + 1e-45

true_distribution = torch.distributions.normal.Normal(mu, sigma)
true_quantiles = true_distribution.icdf(torch.tensor(0.9))

fig2 = plt.figure(2, figsize=(36, 6))
voir_batch2D(true_quantiles, 6, fig2, k=0, min_scale=0.,max_scale=0.1) # ninth decile
fig3 = plt.figure(3, figsize=(36, 6))
voir_batch2D(output.detach().cpu() - true_quantiles, 6, fig3, k=0, min_scale=-0.05,max_scale=0.05) # outputs - ninth decile

# %% [markdown]
# **Exercise 2**: a trickier dependence
#
# Let's now work with the following *gen_proba_2* function.

# %%
from utils_P7 import make_batch
def gen_proba_2(n):
  target1 = make_batch(n, rec = 0., noisy_rec= 0., disc = 0.0015)
  target2 = make_batch(n, rec = 0.001, noisy_rec= 0., disc = 0.)
  m = torch.normal(2, 2. + target2)
  input = target1 + target2
  target = m
  return  input, target

# %% [markdown]
# Here, the dependence of $y$ upon $x$ is not clearly visible in the input-target pairs:

# %%
input, target = gen_proba_2(6)
# Inputs
fig0 = plt.figure(0, figsize=(36, 6))
voir_batch2D(input, 6, fig0, k=0, min_scale=0,max_scale=1)

# Targets
fig1 = plt.figure(1, figsize=(36, 6))
voir_batch2D(target, 6, fig1, k=0, min_scale=0,max_scale=5)

# %% [markdown]
# **Q1** Estimate the 0.1 quantiles of the marginal distributions and visualize the result.

# %%
def criterion(output, target):
  return torch.mean(rho(target-output, 0.1))  #on vise le premier décile

nepochs = 50
nbatches = 100
batchsize = 64

train_losses = []

for epoch in range(nepochs):

    print("Epoch " + str(epoch))
    epoch_losses  = []
    for i in range(nbatches):    # nbatch = datasetsize/batchsize

        input, target = gen_proba(nbatches)

        output = fcn(input.to(device))

        loss = criterion(output,target.to(device))

        loss.backward()

        epoch_losses.append(loss.cpu().detach().numpy())

        optimizer.step()

        epoch_losses.append(loss.detach().cpu())

        del target, input, loss
        torch.cuda.empty_cache()

    epoch_loss = np.mean(epoch_losses)
    train_losses.append(epoch_loss)
    print('epoch loss : \n')
    print(epoch_loss)
# Out:
# Epoch 0
# epoch loss :
#
# 0.021313967
# Epoch 1
# epoch loss :
#
# 0.026774893
# Epoch 2
# epoch loss :
#
# 0.020601347
# Epoch 3
# epoch loss :
#
# 0.009030368
# Epoch 4
# epoch loss :
#
# 0.013571851
# Epoch 5
# epoch loss :
#
# 0.019708037
# Epoch 6
# epoch loss :
#
# 0.015795154
# Epoch 7
# epoch loss :
#
# 0.013942368
# Epoch 8
# epoch loss :
#
# 0.012153064
# Epoch 9
# epoch loss :
#
# 0.026061222
# Epoch 10
# epoch loss :
#
# 0.034340777
# Epoch 11
# epoch loss :
#
# 0.03534673
# Epoch 12
# epoch loss :
#
# 0.028482258
# Epoch 13
# epoch loss :
#
# 0.014094906
# Epoch 14
# epoch loss :
#
# 0.027681462
# Epoch 15
# epoch loss :
#
# 0.011565652
# Epoch 16
# epoch loss :
#
# 0.028897041
# Epoch 17
# epoch loss :
#
# 0.04123442
# Epoch 18
# epoch loss :
#
# 0.049191616
# Epoch 19
# epoch loss :
#
# 0.053614322
# Epoch 20
# epoch loss :
#
# 0.052126475
# Epoch 21
# epoch loss :
#
# 0.04455766
# Epoch 22
# epoch loss :
#
# 0.03206999
# Epoch 23
# epoch loss :
#
# 0.016066574
# Epoch 24
# epoch loss :
#
# 0.027256453
# Epoch 25
# epoch loss :
#
# 0.025274796
# Epoch 26
# epoch loss :
#
# 0.01862892
# Epoch 27
# epoch loss :
#
# 0.03416567
# Epoch 28
# epoch loss :
#
# 0.045895167
# Epoch 29
# epoch loss :
#
# 0.054480303
# Epoch 30
# epoch loss :
#
# 0.060059227
# Epoch 31
# epoch loss :
#
# 0.062519334
# Epoch 32
# epoch loss :
#
# 0.061546903
# Epoch 33
# epoch loss :
#
# 0.05684665
# Epoch 34
# epoch loss :
#
# 0.048256516
# Epoch 35
# epoch loss :
#
# 0.03600584
# Epoch 36
# epoch loss :
#
# 0.02083598
# Epoch 37
# epoch loss :
#
# 0.0123697445
# Epoch 38
# epoch loss :
#
# 0.05881071
# Epoch 39
# epoch loss :
#
# 0.011380599
# Epoch 40
# epoch loss :
#
# 0.023465982
# Epoch 41
# epoch loss :
#
# 0.037769552
# Epoch 42
# epoch loss :
#
# 0.04924088
# Epoch 43
# epoch loss :
#
# 0.0583408
# Epoch 44
# epoch loss :
#
# 0.06518053
# Epoch 45
# epoch loss :
#
# 0.06977172
# Epoch 46
# epoch loss :
#
# 0.071960755
# Epoch 47
# epoch loss :
#
# 0.07150881
# Epoch 48

# %%
#visualisation:

fcn.eval()

input, target = gen_proba_2(6)

...

fig = plt.figure(0, figsize=(36, 6))
voir_batch2D(input, 6, fig, k=0, min_scale=0,max_scale=1)
fig1 = plt.figure(1, figsize=(36, 6))
voir_batch2D(output.detach().cpu(), 6, fig1, k=0, min_scale=-1,max_scale=0.8)

# %% [markdown]
# **Q2** Do outputs depend on inputs? Is it a pixel-wise dependence as in exercise 1? (i.e., does the distribution of $y_{i,j}$ depend only on $x_{i,j}$)

# %% [markdown]
# **Exercise 3**:
#
# One can attempt to estimate $n$ quantiles simultaneously. To achieve this, the simplest way is to:
#
# * change the number of output channels of the U-Net—e.g., 99 channels if you are estimating the $n = 100$ quantiles of orders 1%, 2%, ... 99%.
# * define the overall cost function by summing individual cost functions for each of the channels.
# The goal of this exercise is to code a matrix version of this overall cost function and illustrate the convergence of the learning process.

# %% [markdown]
# **Q1** Let $t$ be a vector of size $n-1$, and $M$ be a 4th-order tensor. Code the function: $$dot(t, M) = M^{\prime}$$ where: $$M^{\prime}_{b,i,j} = \underset{0<c<n}{\sum} t_c \times M_{b,c,i,j}$$.
#
# This function will allow to apply $\rho_{t_c}$ (see **Exercise 1**) to each channel $c$ of the output $M$ (where $b$ represents the batch index and $i,j$ represent spatial dimensions).

# %%
def dot(t, M):
	return ...

# %% [markdown]
# **Q2** Complete the class *QuantileLoss*:

# %%
class QuantileLoss(torch.nn.Module):

    def __init__(self , n):
        super(QuantileLoss, self).__init__()
        self.n = n   # n= 100 -> centiles
        self.t = torch.arange(1/n,1,1/n).cuda()  # quantile orders

    def forward(self, output, target):
        bs, _, nx, ny = target.shape
        ...
        loss = torch.mean(loss_by_pix)

        return loss

# %% [markdown]
# **Q3** Start the training with *gen_proba* and $n=100$, then evaluate the estimation.
